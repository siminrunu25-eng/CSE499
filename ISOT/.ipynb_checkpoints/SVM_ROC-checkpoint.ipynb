# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import string
import re

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
true_path = 'True.csv'
fake_path = 'Fake.csv'

true_df = pd.read_csv(true_path)
fake_df = pd.read_csv(fake_path)

# %%
true_df['true'] = 1
fake_df['true'] = 0

df = pd.concat([true_df, fake_df])
display(df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 23476  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...   Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 23479  21st Century Wire says Al Jazeera America will...   Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  true
# 0      December 31, 2017      1
# 1      December 29, 2017      1
# 2      December 31, 2017      1
# 3      December 30, 2017      1
# 4      December 29, 2017      1
# ...                   ...   ...
# 23476    January 16, 2016     0
# 23477    January 16, 2016     0
# 23478    January 15, 2016     0
# 23479    January 14, 2016     0
# 23480    January 12, 2016     0
#
# [44898 rows x 5 columns]

# %%
true_counts = df['true'].value_counts()

print("Number of Total True News:", true_counts[1])
print("Number of Total Fake news:", true_counts[0])
# Out:
# Number of Total True News: 21417
# Number of Total Fake news: 23481

# %%
df.drop_duplicates()
df.dropna()
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 23476  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...   Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 23479  21st Century Wire says Al Jazeera America will...   Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  true
# 0      December 31, 2017      1
# 1      December 29, 2017      1
# 2      December 31, 2017      1
# 3      December 30, 2017      1
# 4      December 29, 2017      1
# ...                   ...   ...
# 23476    January 16, 2016     0
# 23477    January 16, 2016     0
# 23478    January 15, 2016     0
# 23479    January 14, 2016     0
# 23480    January 12, 2016     0
#
# [44898 rows x 5 columns]

# %%
df.drop(columns = ["text","subject","date"])
# Out:
#                                                    title  true
# 0      As U.S. budget fight looms, Republicans flip t...     1
# 1      U.S. military to accept transgender recruits o...     1
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...     1
# 3      FBI Russia probe helped by Australian diplomat...     1
# 4      Trump wants Postal Service to charge 'much mor...     1
# ...                                                  ...   ...
# 23476  McPain: John McCain Furious That Iran Treated ...     0
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...     0
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...     0
# 23479  How to Blow $700 Million: Al Jazeera America F...     0
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...     0
#
# [44898 rows x 2 columns]

# %%
from sklearn.utils import shuffle

df = df.iloc[:,[0,-1]]
df = df.sample(frac=1).reset_index(drop=True)
display(df)
# Out:
#                                                    title  true
# 0      Tillerson urges Iraq, Kurds to resolve conflic...     1
# 1      U.S. service member killed in Afghanistan heli...     1
# 2       Trump Tells Democrats To Kiss His A** After S...     0
# 3      FLASHBACK: EPIC FAIL When CNN’s Interview Of S...     0
# 4                      Countdown to Brexit breakthrough?     1
# ...                                                  ...   ...
# 44893  U.S. formally accuses Russian hackers of polit...     1
# 44894  WATCH…TX SHERIFF WARNS LOOTERS: “Think Twice B...     0
# 44895  “IT’S A WAR!”…Armed Illegal Aliens Are Running...     0
# 44896  HOMELAND SECURITY: ISIS Has Already Tried To E...     0
# 44897  LANGUAGE WARNING BUT SO FUNNY! LISTEN TO TWO B...     0
#
# [44898 rows x 2 columns]

# %%
df['title'] = (df['title'].str.lower())
print(df)
# Out:
#                                                    title  true
# 0      tillerson urges iraq, kurds to resolve conflic...     1
# 1      u.s. service member killed in afghanistan heli...     1
# 2       trump tells democrats to kiss his a** after s...     0
# 3      flashback: epic fail when cnn’s interview of s...     0
# 4                      countdown to brexit breakthrough?     1
# ...                                                  ...   ...
# 44893  u.s. formally accuses russian hackers of polit...     1
# 44894  watch…tx sheriff warns looters: “think twice b...     0
# 44895  “it’s a war!”…armed illegal aliens are running...     0
# 44896  homeland security: isis has already tried to e...     0
# 44897  language warning but so funny! listen to two b...     0
#
# [44898 rows x 2 columns]

# %%
df['title'] = df['title'].str.replace('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ')
df.head()
# Out:
#                                                title  true
# 0  tillerson urges iraq, kurds to resolve conflic...     1
# 1  u.s. service member killed in afghanistan heli...     1
# 2   trump tells democrats to kiss his a** after s...     0
# 3  flashback: epic fail when cnn’s interview of s...     0
# 4                  countdown to brexit breakthrough?     1

# %%
df['title'] = df['title'].str.replace(r"[\"\'\|\?\=\.\<\>\@\#\*\,]", '')
df.head()
# Out:
#                                                title  true
# 0  tillerson urges iraq kurds to resolve conflict...     1
# 1  us service member killed in afghanistan helico...     1
# 2   trump tells democrats to kiss his a after spe...     0
# 3  flashback: epic fail when cnn’s interview of s...     0
# 4                   countdown to brexit breakthrough     1

# %%
def tokenize(txt):
    tokens = re.split('\W+', txt)
    return tokens

# %%
df['title'] = df['title'].apply(lambda x: tokenize(x.lower()))
df.head()
# Out:
#                                                title  true
# 0  [tillerson, urges, iraq, kurds, to, resolve, c...     1
# 1  [us, service, member, killed, in, afghanistan,...     1
# 2  [, trump, tells, democrats, to, kiss, his, a, ...     0
# 3  [flashback, epic, fail, when, cnn, s, intervie...     0
# 4              [countdown, to, brexit, breakthrough]     1

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(txt):
    txt_nopunct = " ".join([c for c in txt if c not in string.punctuation])
    return txt_nopunct

# %%
df['title'] = df['title'].apply(lambda x : remove_punctuation(x))
df.head()
# Out:
#                                                title  true
# 0  tillerson urges iraq kurds to resolve conflict...     1
# 1  us service member killed in afghanistan helico...     1
# 2  trump tells democrats to kiss his a after spec...     0
# 3  flashback epic fail when cnn s interview of sy...     0
# 4                   countdown to brexit breakthrough     1

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
",".join(stopwords.words('english'))
# Out:
# "i,me,my,myself,we,our,ours,ourselves,you,you're,you've,you'll,you'd,your,yours,yourself,yourselves,he,him,his,himself,she,she's,her,hers,herself,it,it's,its,itself,they,them,their,theirs,themselves,what,which,who,whom,this,that,that'll,these,those,am,is,are,was,were,be,been,being,have,has,had,having,do,does,did,doing,a,an,the,and,but,if,or,because,as,until,while,of,at,by,for,with,about,against,between,into,through,during,before,after,above,below,to,from,up,down,in,out,on,off,over,under,again,further,then,once,here,there,when,where,why,how,all,any,both,each,few,more,most,other,some,such,no,nor,not,only,own,same,so,than,too,very,s,t,can,will,just,don,don't,should,should've,now,d,ll,m,o,re,ve,y,ain,aren,aren't,couldn,couldn't,didn,didn't,doesn,doesn't,hadn,hadn't,hasn,hasn't,haven,haven't,isn,isn't,ma,mightn,mightn't,mustn,mustn't,needn,needn't,shan,shan't,shouldn,shouldn't,wasn,wasn't,weren,weren't,won,won't,wouldn,wouldn't"

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove_stop(x):
    return ",".join([word for word in str(x).split() if word not in stop_words])

# %%
df['title'] = df['title'].apply(lambda x : remove_stop(x))
df.head()
# Out:
#                                                title  true
# 0  tillerson,urges,iraq,kurds,resolve,conflict,di...     1
# 1  us,service,member,killed,afghanistan,helicopte...     1
# 2  trump,tells,democrats,kiss,special,election,in...     0
# 3  flashback,epic,fail,cnn,interview,syrian,victi...     0
# 4                      countdown,brexit,breakthrough     1

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer = WordNetLemmatizer()

# %%
def data_processing(data):
    data = [lemmatizer.lemmatize(word) for word in data]
    data = ''.join(data)
    return data

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
df['title'] = df['title'].apply(lambda data: data_processing(data))
df.head()
# Out:
#                                                title  true
# 0  tillerson,urges,iraq,kurds,resolve,conflict,di...     1
# 1  us,service,member,killed,afghanistan,helicopte...     1
# 2  trump,tells,democrats,kiss,special,election,in...     0
# 3  flashback,epic,fail,cnn,interview,syrian,victi...     0
# 4                      countdown,brexit,breakthrough     1

# %%
train_df = df.sample(frac=0.8)
test_df = df.drop(train_df.index)

# reset index
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

print('trainset size:', train_df.shape)
print('testset size:', test_df.shape)
# Out:
# trainset size: (35918, 2)
# testset size: (8980, 2)

# %%
print('ISOT length:', len(test_df))

print('Train real news:', train_df[train_df['true']==1].shape[0])
print('Train fake news:', train_df[train_df['true']==0].shape[0])

print('Test real news:', test_df[test_df['true']==1].shape[0])
print('Test fake news:', test_df[test_df['true']==0].shape[0])
# Out:
# ISOT length: 8980
# Train real news: 17160
# Train fake news: 18758
# Test real news: 4257
# Test fake news: 4723

# %%
X_train = train_df['title']
X_test = test_df['title']

y_train = train_df['true']
y_test = test_df['true']

print('Train data:', X_train.shape, y_train.shape)
print('Test data:', X_test.shape, y_test.shape)
# Out:
# Train data: (35918,) (35918,)
# Test data: (8980,) (8980,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(min_df=10)

X_train_news_tfidf = vectorizer.fit_transform(X_train)
X_test_news_tfidf = vectorizer.transform(X_test)

print('X_train_news_tfidf shape:', X_train_news_tfidf.shape)
print('X_test_news_tfidf shape:', X_test_news_tfidf.shape)
# Out:
# X_train_news_tfidf shape: (35918, 4888)
# X_test_news_tfidf shape: (8980, 4888)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_curve
from sklearn.metrics import auc

clf = SVC()

param_grid = {'C':[0.1,1,10,100], 'kernel':['linear','rbf','poly','sigmoid']}

grid_search = GridSearchCV(clf, param_grid, cv=5, scoring='f1')
grid_search.fit(X_train_news_tfidf, y_train)

best_params = grid_search.best_params_

final_clf = SVC(probability=True, **best_params)
final_clf.fit(X_train_news_tfidf, y_train)

y_pred = final_clf.predict(X_test_news_tfidf)
y_prob = final_clf.predict_proba(X_test_news_tfidf)[:,1]

accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

print('SVM Classifier')
print('Best hyperparameters:', best_params)
print('Accuracy: ', accuracy)
print('Precision: ', precision)
print('Recall: ', recall)
print('F1-score: ', f1)
print('AUC Score: ', roc_auc)

plt.figure(figsize = (5,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve(AUC= {:.2f})'.format(roc_auc))
plt.plot([0,1], [0,1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate -->')
plt.ylabel('True Positve Rate -->')
plt.title('ROC curve for SVM')
plt.legend(loc='lower right')
plt.show()
# Out:
# SVM Classifier
# Best hyperparameters: {'C': 100, 'kernel': 'rbf'}
# Accuracy:  0.9571269487750557
# Precision:  0.9533957845433255
# Recall:  0.95630725863284
# F1-score:  0.9548493022164888
# AUC Score:  0.9922729801846838
