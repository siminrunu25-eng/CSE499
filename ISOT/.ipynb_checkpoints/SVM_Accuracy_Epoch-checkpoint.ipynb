# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import string
import re

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
true_path = 'True.csv'
fake_path = 'Fake.csv'

true_df = pd.read_csv(true_path)
fake_df = pd.read_csv(fake_path)

# %%
true_df['true'] = 1
fake_df['true'] = 0

df = pd.concat([true_df, fake_df])
display(df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 23476  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...   Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 23479  21st Century Wire says Al Jazeera America will...   Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  true
# 0      December 31, 2017      1
# 1      December 29, 2017      1
# 2      December 31, 2017      1
# 3      December 30, 2017      1
# 4      December 29, 2017      1
# ...                   ...   ...
# 23476    January 16, 2016     0
# 23477    January 16, 2016     0
# 23478    January 15, 2016     0
# 23479    January 14, 2016     0
# 23480    January 12, 2016     0
#
# [44898 rows x 5 columns]

# %%
true_counts = df['true'].value_counts()

print("Number of Total True News:", true_counts[1])
print("Number of Total Fake news:", true_counts[0])
# Out:
# Number of Total True News: 21417
# Number of Total Fake news: 23481

# %%
df.drop_duplicates()
df.dropna()
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 23476  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...   Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 23479  21st Century Wire says Al Jazeera America will...   Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  true
# 0      December 31, 2017      1
# 1      December 29, 2017      1
# 2      December 31, 2017      1
# 3      December 30, 2017      1
# 4      December 29, 2017      1
# ...                   ...   ...
# 23476    January 16, 2016     0
# 23477    January 16, 2016     0
# 23478    January 15, 2016     0
# 23479    January 14, 2016     0
# 23480    January 12, 2016     0
#
# [44898 rows x 5 columns]

# %%
df.drop(columns = ["text","subject","date"])
# Out:
#                                                    title  true
# 0      As U.S. budget fight looms, Republicans flip t...     1
# 1      U.S. military to accept transgender recruits o...     1
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...     1
# 3      FBI Russia probe helped by Australian diplomat...     1
# 4      Trump wants Postal Service to charge 'much mor...     1
# ...                                                  ...   ...
# 23476  McPain: John McCain Furious That Iran Treated ...     0
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...     0
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...     0
# 23479  How to Blow $700 Million: Al Jazeera America F...     0
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...     0
#
# [44898 rows x 2 columns]

# %%
from sklearn.utils import shuffle

df = df.iloc[:,[0,-1]]
df = df.sample(frac=1).reset_index(drop=True)
display(df)
# Out:
#                                                    title  true
# 0      FED UP WITH #BlackLivesMatter Terrorists: Stud...     0
# 1      Senate advances on healthcare, with dramatic r...     1
# 2      Merkel says three-way coalition can work, Gree...     1
# 3      Hamas cedes Gaza border crossings to Palestini...     1
# 4      Czech PM candidate Babis to face fraud charges...     1
# ...                                                  ...   ...
# 44893  Brazil declares top Venezuelan diplomat person...     1
# 44894   Watch Glenn Beck’s BIZARRE Ritual With Child ...     0
# 44895   Secret Report: Top Russians Celebrated Trump Win     0
# 44896  Argentina fires head of navy over submarine tr...     1
# 44897   This Christian Mom Thought It Was A Good Idea...     0
#
# [44898 rows x 2 columns]

# %%
df['title'] = (df['title'].str.lower())
print(df)
# Out:
#                                                    title  true
# 0      fed up with #blacklivesmatter terrorists: stud...     0
# 1      senate advances on healthcare, with dramatic r...     1
# 2      merkel says three-way coalition can work, gree...     1
# 3      hamas cedes gaza border crossings to palestini...     1
# 4      czech pm candidate babis to face fraud charges...     1
# ...                                                  ...   ...
# 44893  brazil declares top venezuelan diplomat person...     1
# 44894   watch glenn beck’s bizarre ritual with child ...     0
# 44895   secret report: top russians celebrated trump win     0
# 44896  argentina fires head of navy over submarine tr...     1
# 44897   this christian mom thought it was a good idea...     0
#
# [44898 rows x 2 columns]

# %%
df['title'] = df['title'].str.replace('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ')
df.head()
# Out:
#                                                title  true
# 0  fed up with #blacklivesmatter terrorists: stud...     0
# 1  senate advances on healthcare, with dramatic r...     1
# 2  merkel says three-way coalition can work, gree...     1
# 3  hamas cedes gaza border crossings to palestini...     1
# 4  czech pm candidate babis to face fraud charges...     1

# %%
df['title'] = df['title'].str.replace(r"[\"\'\|\?\=\.\<\>\@\#\*\,]", '')
df.head()
# Out:
#                                                title  true
# 0  fed up with blacklivesmatter terrorists: stude...     0
# 1  senate advances on healthcare with dramatic re...     1
# 2  merkel says three-way coalition can work green...     1
# 3  hamas cedes gaza border crossings to palestini...     1
# 4  czech pm candidate babis to face fraud charges...     1

# %%
def tokenize(txt):
    tokens = re.split('\W+', txt)
    return tokens

# %%
df['title'] = df['title'].apply(lambda x: tokenize(x.lower()))
df.head()
# Out:
#                                                title  true
# 0  [fed, up, with, blacklivesmatter, terrorists, ...     0
# 1  [senate, advances, on, healthcare, with, drama...     1
# 2  [merkel, says, three, way, coalition, can, wor...     1
# 3  [hamas, cedes, gaza, border, crossings, to, pa...     1
# 4  [czech, pm, candidate, babis, to, face, fraud,...     1

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(txt):
    txt_nopunct = " ".join([c for c in txt if c not in string.punctuation])
    return txt_nopunct

# %%
df['title'] = df['title'].apply(lambda x : remove_punctuation(x))
df.head()
# Out:
#                                                title  true
# 0  fed up with blacklivesmatter terrorists studen...     0
# 1  senate advances on healthcare with dramatic re...     1
# 2  merkel says three way coalition can work green...     1
# 3  hamas cedes gaza border crossings to palestini...     1
# 4  czech pm candidate babis to face fraud charges...     1

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
",".join(stopwords.words('english'))
# Out:
# "i,me,my,myself,we,our,ours,ourselves,you,you're,you've,you'll,you'd,your,yours,yourself,yourselves,he,him,his,himself,she,she's,her,hers,herself,it,it's,its,itself,they,them,their,theirs,themselves,what,which,who,whom,this,that,that'll,these,those,am,is,are,was,were,be,been,being,have,has,had,having,do,does,did,doing,a,an,the,and,but,if,or,because,as,until,while,of,at,by,for,with,about,against,between,into,through,during,before,after,above,below,to,from,up,down,in,out,on,off,over,under,again,further,then,once,here,there,when,where,why,how,all,any,both,each,few,more,most,other,some,such,no,nor,not,only,own,same,so,than,too,very,s,t,can,will,just,don,don't,should,should've,now,d,ll,m,o,re,ve,y,ain,aren,aren't,couldn,couldn't,didn,didn't,doesn,doesn't,hadn,hadn't,hasn,hasn't,haven,haven't,isn,isn't,ma,mightn,mightn't,mustn,mustn't,needn,needn't,shan,shan't,shouldn,shouldn't,wasn,wasn't,weren,weren't,won,won't,wouldn,wouldn't"

# %%
stop_words = set(stopwords.words('english'))

# %%
def remove_stop(x):
    return ",".join([word for word in str(x).split() if word not in stop_words])

# %%
df['title'] = df['title'].apply(lambda x : remove_stop(x))
df.head()
# Out:
#                                                title  true
# 0  fed,blacklivesmatter,terrorists,students,major...     0
# 1  senate,advances,healthcare,dramatic,return,mccain     1
# 2  merkel,says,three,way,coalition,work,greens,sk...     1
# 3  hamas,cedes,gaza,border,crossings,palestinian,...     1
# 4   czech,pm,candidate,babis,face,fraud,charges,vote     1

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer = WordNetLemmatizer()

# %%
def data_processing(data):
    data = [lemmatizer.lemmatize(word) for word in data]
    data = ''.join(data)
    return data

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
df['title'] = df['title'].apply(lambda data: data_processing(data))
df.head()
# Out:
#                                                title  true
# 0  fed,blacklivesmatter,terrorists,students,major...     0
# 1  senate,advances,healthcare,dramatic,return,mccain     1
# 2  merkel,says,three,way,coalition,work,greens,sk...     1
# 3  hamas,cedes,gaza,border,crossings,palestinian,...     1
# 4   czech,pm,candidate,babis,face,fraud,charges,vote     1

# %%
train_df = df.sample(frac=0.8)
test_df = df.drop(train_df.index)

# reset index
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

print('trainset size:', train_df.shape)
print('testset size:', test_df.shape)
# Out:
# trainset size: (35918, 2)
# testset size: (8980, 2)

# %%
print('ISOT length:', len(test_df))

print('Train real news:', train_df[train_df['true']==1].shape[0])
print('Train fake news:', train_df[train_df['true']==0].shape[0])

print('Test real news:', test_df[test_df['true']==1].shape[0])
print('Test fake news:', test_df[test_df['true']==0].shape[0])
# Out:
# ISOT length: 8980
# Train real news: 17146
# Train fake news: 18772
# Test real news: 4271
# Test fake news: 4709

# %%
X_train = train_df['title']
X_test = test_df['title']

y_train = train_df['true']
y_test = test_df['true']

print('Train data:', X_train.shape, y_train.shape)
print('Test data:', X_test.shape, y_test.shape)
# Out:
# Train data: (35918,) (35918,)
# Test data: (8980,) (8980,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(min_df=10)

X_train_news_tfidf = vectorizer.fit_transform(X_train)
X_test_news_tfidf = vectorizer.transform(X_test)

print('X_train_news_tfidf shape:', X_train_news_tfidf.shape)
print('X_test_news_tfidf shape:', X_test_news_tfidf.shape)
# Out:
# X_train_news_tfidf shape: (35918, 4922)
# X_test_news_tfidf shape: (8980, 4922)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score

clf = SVC()

param_grid = {'C':[0.1,1,10,100], 'kernel':['linear','rbf','poly','sigmoid']}

grid_search = GridSearchCV(clf, param_grid, cv=5, scoring='f1')
grid_search.fit(X_train_news_tfidf, y_train)

best_params = grid_search.best_params_

final_clf = SVC(**best_params)
final_clf.fit(X_train_news_tfidf, y_train)

y_train_pred = final_clf.predict(X_train_news_tfidf)
train_accuracy = accuracy_score(y_train, y_train_pred)

y_val_pred = final_clf.predict(X_test_news_tfidf)
val_accuracy = accuracy_score(y_test, y_val_pred)

print('SVM Classifier')
print('Best hyperparameters:', best_params)
print('Training Accuracy: ', train_accuracy)
print('Validation Accuracy: ', val_accuracy)

labels = ['Training', 'Validation']
accuracies = [train_accuracy, val_accuracy]

plt.bar(labels, accuracies, color=['blue', 'orange'])
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.show()
# Out:
# SVM Classifier
# Best hyperparameters: {'C': 10, 'kernel': 'rbf'}
# Training Accuracy:  1.0
# Validation Accuracy:  0.9611358574610245
